# %% [markdown]
# Google Docs File: https://docs.google.com/document/d/1OnK-tSjOFlQJrF49xx1Cv8-CImZUlQPDquK0hIE8P5Q/edit?tab=t.0

# %%
from selenium import webdriver
driver = webdriver.Chrome()


from selenium.webdriver.common.by import By
#opens a new Chrome window
driver.get("https://www.google.com")

# %%
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
#sample website access to Myntra

# use a for loop- for link in links - custom links saved in link list...then retrieve it 
driver.get("https://www.myntra.com/dresses?f=Gender%3Amen%20women%2Cwomen&sort=popularity")

# %%
title = driver.title
title
# Out:
# 'Dresses Online - Low Price Offer on Dresses for Women at Myntra'

# %%
#default syntax to access the items using the id of the products
#driver.find_element(by=By.Name, value="my-text")
product= driver.find_element(by=By.ID, value="25323250")
product.text


#product #we got the selenium element
# Out:
# '4.3\n|\n1.3k\nStyleCast\nBodycon Maxi Dress\nRs. 1069Rs. 3149(Rs. 2080 OFF)'

# %%
def extract_product_info(li_element):
   product_id = li_element.get_attribute("id")
   print(product_id)


   if product_id is None:
       return None
   try:
       # Locate the product metadata container
       product_meta_info = li_element.find_element(By.CLASS_NAME, "product-productMetaInfo")
      
       # Extract the product id
       product_id = li_element.get_attribute("id")


       # Extract the brand
       brand = product_meta_info.find_element(By.CLASS_NAME, "product-brand").text


       # Extract the product name
       product_name = product_meta_info.find_element(By.CLASS_NAME, "product-product").text
      
       # Extract the price
       price = _extract_product_price(product_meta_info)


       # Locate the image slider container
       image_slider = li_element.find_element(By.CLASS_NAME, "product-imageSliderContainer")


       # Extract the <img> tag inside the <picture> tag
       img_tag = image_slider.find_element(By.TAG_NAME, "img")
       image_url = img_tag.get_attribute("src")
          
       # Extract the product link
       product_link = li_element.find_element(By.TAG_NAME, "a").get_attribute("href")


       # Extract the product rating
       rating, count = _extract_rating_data(li_element)


       return {
           "id": product_id,
           "brand": brand,
           "product_name": product_name,
           "price": price,
           "rating:": rating,
           "count": count,
           "image_url": image_url,
           "product_link": product_link,
       }


   except Exception as e:
       print(f"Error extracting product info from <li>: {e}")
       return None
  


def _extract_product_price(product_meta_info):
   price_container = product_meta_info.find_element(By.CLASS_NAME, "product-price")
  
   # Check if discounted price is present
   price = {"Discounted": 0, "Original": 0}
   try:
       discounted_price = price_container.find_element(By.CLASS_NAME, "product-discountedPrice").text.replace("Rs. ", "").strip()
       original_price = price_container.find_element(By.CLASS_NAME, "product-strike").text.replace("Rs. ", "").strip()
       # price = f"Discounted: {discounted_price}, Original: {original_price}"
       price["Discounted"]= discounted_price
       price["Original"]= original_price
      
   except:
       # If discounted price is not present, fall back to the single price
       original_price = price_container.find_element(By.TAG_NAME, "span").text.replace("Rs. ", "").strip()
       price["Original"] = original_price


   return price



def _extract_rating_data(li_element):
   try:
       # Locate the ratings container
       ratings_container = li_element.find_element(By.CLASS_NAME, "product-ratingsContainer")
      
       # Extract the rating value (e.g., 4)
       rating_value = ratings_container.find_element(By.TAG_NAME, "span").text
      
       # Extract the ratings count (e.g., 872)
       ratings_count_container = ratings_container.find_element(By.CLASS_NAME, "product-ratingsCount")
       ratings_count = ratings_count_container.text.split('|')[-1].strip()


       return rating_value, ratings_count
  
   except Exception as e:
       print(f"Error extracting data from an <li>: {e}")
       return None, None

# %%
# Locate the main container
container = driver.find_element(By.ID, "desktopSearchResults")


# Locate the nested container
search_container = container.find_element(By.CLASS_NAME, "search-searchProductsContainer.row-base")


# Locate all <li> elements inside <section> > <ul>
li_elements = search_container.find_elements(By.CSS_SELECTOR, "section > ul > li")


product_data = []


# Iterate through each <li> and get inner data
for id, li in enumerate(li_elements):
   # print(li.text)  # Or use li.get_attribute("innerHTML") for raw HTML content


   product_info = extract_product_info(li)

   if product_info is not None:
       print(product_info)
       product_data.append(product_info)

   #error handling- for just understanding
   if id >= 2:
        break
# Out:
# 25892106
# {'id': '25892106', 'brand': 'H&M', 'product_name': 'Ruched Sleeve Wrap Dress', 'price': {'Discounted': 0, 'Original': '1799'}, 'rating:': '4', 'count': '881', 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/25892106/2024/10/24/1aaf1645-3589-4aee-80de-3ed6ff7df3751729768804020-HM-Ruched-Sleeve-Wrap-Dress-5241729768803665-1.jpg', 'product_link': 'https://www.myntra.com/dresses/h%26m/hm-ruched-sleeve-wrap-dress/25892106/buy'}
# 25323250
# {'id': '25323250', 'brand': 'StyleCast', 'product_name': 'Bodycon Maxi Dress', 'price': {'Discounted': '1069', 'Original': '3149'}, 'rating:': '4.3', 'count': '1.3k', 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/25323250/2023/10/5/31a1cef6-74e2-492b-ae4b-958f338fea2d1696448955699StyleCastRedBodyconMaxiDress1.jpg', 'product_link': 'https://www.myntra.com/dresses/stylecast/stylecast-red-shoulder-straps-bodycon-maxi-dress/25323250/buy'}
# 29951378
# {'id': '29951378', 'brand': 'Antheaa', 'product_name': 'Tie and Dye Print Crepe A-Line Midi Puff Sleeve Dress', 'price': {'Discounted': '1199', 'Original': '2499'}, 'rating:': '4', 'count': '767', 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/29951378/2024/6/12/e4aee740-b23b-499d-958a-692e1b51bc941718204163906AntheaaTieandDyePrintPuffSleeveCrepeA-LineMidiDress1.jpg', 'product_link': 'https://www.myntra.com/dresses/antheaa/antheaa-tie-and-dye-print-puff-sleeve-crepe-a-line-midi-dress/29951378/buy'}

# %%
try:
    # Locate the rating element (adjust class name as necessary)
    rating_element = driver.find_element(By.CLASS_NAME, "rating-value")  # Example class name; adjust as needed
    rating = rating_element.text
    
    # Locate the count of verified buyers (adjust class name as necessary)
    count_element = driver.find_element(By.CLASS_NAME, "rating-count")  # Example class name; adjust as needed
    count = count_element.text
    
    print(f"Rating: {rating}, Verified Buyers Count: {count}")

except Exception as e:
    print(f"Error extracting rating data: {e}")
# Out:
# Error extracting rating data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".rating-value"}
#   (Session info: chrome=131.0.6778.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF761636CC5+28821]
# 	(No symbol) [0x00007FF7615A3850]
# 	(No symbol) [0x00007FF76144578A]
# 	(No symbol) [0x00007FF7614991BE]
# 	(No symbol) [0x00007FF7614994AC]
# 	(No symbol) [0x00007FF7614E2647]
# 	(No symbol) [0x00007FF7614BF33F]
# 	(No symbol) [0x00007FF7614DF412]
# 	(No symbol) [0x00007FF7614BF0A3]
# 	(No symbol) [0x00007FF76148A778]
# 	(No symbol) [0x00007FF76148B8E1]
# 	GetHandleVerifier [0x00007FF76196FCCD+3408029]
# 	GetHandleVerifier [0x00007FF76198743F+3504143]
# 	GetHandleVerifier [0x00007FF76197B61D+3455469]
# 	GetHandleVerifier [0x00007FF7616FBDCB+835995]
# 	(No symbol) [0x00007FF7615AEB6F]
# 	(No symbol) [0x00007FF7615AA824]
# 	(No symbol) [0x00007FF7615AA9BD]
# 	(No symbol) [0x00007FF76159A1A9]
# 	BaseThreadInitThunk [0x00007FFC5F5BE8D7+23]
# 	RtlUserThreadStart [0x00007FFC60B7FBCC+44]

# %%
# Export data to Excel
if product_data:
   # Create a DataFrame from the list of dictionaries
   df = pd.DataFrame(product_data)


   # Write the DataFrame to an Excel file
   excel_file = "product_data.xlsx"
   df.to_excel(excel_file, index=False)
   print(f"Data successfully exported to {excel_file}")
else:
   print("No data to export.")
# Out:
# Data successfully exported to product_data.xlsx

# %% [markdown]
# Implemented the Infinite Scroll feature

# %%
# Function to implement infinite scrolling

def infinite_scroll(driver):
    # Get the initial height of the document
    last_height = driver.execute_script("return document.body.scrollHeight")
    
    while True:
        # Scroll down to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        
        # Wait for new content to load; duration may need adjustment based on network speed
        time.sleep(2)  # Adjust this sleep time according to your needs
        
        # Get the new height of the document after scrolling
        new_height = driver.execute_script("return document.body.scrollHeight")
        
        # Check if the new height is equal to the last height
        # If they are equal, it means no new content has been loaded, and we can exit the loop
        if new_height == last_height:
            break  # Exit the loop if no new content is loaded
        
        # Update last_height for the next iteration
        last_height = new_height

# Call the infinite scroll function to load all products
infinite_scroll(driver)

# Call the infinite scroll function to load all products
infinite_scroll(driver)

# Function to extract product information from a list item element
def extract_product_info(li_element):
    try:
        product_meta_info = li_element.find_element(By.CLASS_NAME, "product-productMetaInfo")
        product_id = li_element.get_attribute("id")
        brand = product_meta_info.find_element(By.CLASS_NAME, "product-brand").text
        product_name = product_meta_info.find_element(By.CLASS_NAME, "product-product").text
        price = _extract_product_price(product_meta_info)
        image_slider = li_element.find_element(By.CLASS_NAME, "product-imageSliderContainer")
        img_tag = image_slider.find_element(By.TAG_NAME, "img")
        image_url = img_tag.get_attribute("src")
        product_link = li_element.find_element(By.TAG_NAME, "a").get_attribute("href")
        rating, count = _extract_rating_data(li_element)

        return {
            "id": product_id,
            "brand": brand,
            "product_name": product_name,
            "price": price,
            "rating": rating,
            "count": count,
            "image_url": image_url,
            "product_link": product_link,
        }

    except Exception as e:
        print(f"Error extracting product info from <li>: {e}")
        return None

def _extract_product_price(product_meta_info):
    price_container = product_meta_info.find_element(By.CLASS_NAME, "product-price")
    price = {"Discounted": 0, "Original": 0}
    
    try:
        discounted_price = price_container.find_element(By.CLASS_NAME, "product-discountedPrice").text.replace("Rs. ", "").strip()
        original_price = price_container.find_element(By.CLASS_NAME, "product-strike").text.replace("Rs. ", "").strip()
        price["Discounted"] = discounted_price
        price["Original"] = original_price

    except:
        original_price = price_container.find_element(By.TAG_NAME, "span").text.replace("Rs. ", "").strip()
        price["Original"] = original_price

    return price

def _extract_rating_data(li_element):
    try:
        ratings_container = li_element.find_element(By.CLASS_NAME, "product-ratingsContainer")
        rating_value = ratings_container.find_element(By.TAG_NAME, "span").text
        ratings_count_container = ratings_container.find_element(By.CLASS_NAME, "product-ratingsCount")
        ratings_count = ratings_count_container.text.split('|')[-1].strip()

        return rating_value, ratings_count

    except Exception as e:
        print(f"Error extracting data from an <li>: {e}")
        return None, None

# Locate the main container for products after scrolling
container = driver.find_element(By.ID, "desktopSearchResults")
search_container = container.find_element(By.CLASS_NAME, "search-searchProductsContainer.row-base")

# Locate all <li> elements inside <section> > <ul>
li_elements = search_container.find_elements(By.CSS_SELECTOR, "section > ul > li")

product_data = []

# Iterate through each <li> and get inner data
for id, li in enumerate(li_elements):
    product_info = extract_product_info(li)
    if product_info:
        product_data.append(product_info)
        print(product_info)  # Print each product's information

# Export data to Excel if available
if product_data:
    df = pd.DataFrame(product_data)
    excel_file = "product_data.xlsx"
    df.to_excel(excel_file, index=False)
    print(f"Data successfully exported to {excel_file}")

    #replace the rating : thing after u have exported the file
else:
    print("No data to export.")

# Close the driver
driver.quit()
# Out:
# {'id': '25892106', 'brand': 'H&M', 'product_name': 'Ruched Sleeve Wrap Dress', 'price': {'Discounted': 0, 'Original': '1799'}, 'rating': '4', 'count': '881', 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images

# 	(No symbol) [0x00007FF7614DF412]
# 	(No symbol) [0x00007FF7614BF0A3]
# 	(No symbol) [0x00007FF76148A778]
# 	(No symbol) [0x00007FF76148B8E1]
# 	GetHandleVerifier [0x00007FF76196FCCD+3408029]
# 	GetHandleVerifier [0x00007FF76198743F+3504143]
# 	GetHandleVerifier [0x00007FF76197B61D+3455469]
# 	GetHandleVerifier [0x00007FF7616FBDCB+835995]
# 	(No symbol) [0x00007FF7615AEB6F]
# 	(No symbol) [0x00007FF7615AA824]
# 	(No symbol) [0x00007FF7615AA9BD]
# 	(No symbol) [0x00007FF76159A1A9]
# 	BaseThreadInitThunk [0x00007FFC5F5BE8D7+23]
# 	RtlUserThreadStart [0x00007FFC60B7FBCC+44]
#
# {'id': '31660332', 'brand': 'StyleCast x Revolte', 'product_name': 'Women A-Line Midi Dress', 'price': {'Discounted': '1459', 'Original': '3949'}, 'rating': None, 'count': None, 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/2024/NOVEMBER/18/8AfypiEK_50a3790a70704c848c571e5b8a059cac.jpg', 'product_link': 'https://www.myntra.com/dresses/stylecast+x+revolte/stylecast-x-revolte-women-a-line-midi-dress/31660332/buy'}
# {'id': '18788368', 'brand': 'Vishudh', 'product_name': 'Maxi Dress', 'price': {'Discounted': '884', 'Original': '3049'}, 'rating': '4.1', 'count': '1.6k', 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/18788368/2022/6/20/3c29169b-fd68-4471-8dfc-ce44e470f5a91655719370416Dresses1.jpg', 'product_link': 'https://www.myntra.com/ethnic-dresses/vishudh/vishudh-maroon-ethnic-maxi-dress/18788368/buy'}
# {'id': '30639836', 'brand': 'Antheaa', 'product_name': 'A-Line Knee Length Dress', 'price': {'Discounted': '1854', 'Original': '3499'}, 'rating': '4.4', 'count': '92', 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/30639836/2024/8/29/95b5f696-1f50-4ad4-b5c5-8f21bbb5c3ad1724919824192-Antheaa-Chiffon-A-Line-Knee-Length-Dress-341724919823561-1.jpg', 'product_link': 'https://www.myntra.com/dresses/antheaa/antheaa-chiffon-embroidered-a-line-knee-length-dress/30639836/buy'}
# {'id': '30674696', 'brand': 'Boho By Athena', 'product_name': 'Floral Print A-Line Maxi Dress', 'price': {'Discounted': '999', 'Original': '2499'}, 'rating': '4.3', 'count': '198', 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/2024/AUGUST/22/ICLWkjBx_4b5f8f61d9d94a408d644241f9e78358.jpg', 'product_link': 'https://www.myntra.com/dresses/boho+by+athena/boho-by-athena-floral-print-a-line-maxi-dress/30674696/buy'}
# {'id': '29712800', 'brand': 'Boho By Athena', 'product_name': 'Printed A-Line Midi Dress', 'price': {'Discounted': '1319', 'Original': '3299'}, 'rating': '3.9', 'count': '236', 'image_url': 'https://assets.myntassets.com/dpr_2,q_60,w_210,c_limit,fl_progressive/assets/images/29712800/2024/5/23/064eb9f2-9aa3-4eab-aced-ae1b71d3c3bf1716454665930BohoByAthenaPrintA-LineMidiDress1.jpg', 'product_link': 'https://www.myntra.com/dresses/boho+by+athena/boho-by-athena-printed-a-line-midi-dress/29712800/buy'}
# Error extracting product info from <li>: Message: no such element: Unable to locate element: {"method":"css selector","selector":".product-productMetaInfo"}
#   (Session info: chrome=131.0.6778.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF761636CC5+28821]
# 	(No symbol) [0x00007FF7615A3850]
# 	(No symbol) [0x00007FF76144578A]
# 	(No symbol) [0x00007FF7614991BE]
# 	(No symbol) [0x00007FF7614994AC]
# 	(No symbol) [0x00007FF76148C52C]
# 	(No symbol) [0x00007FF7614BF33F]
# 	(No symbol) [0x00007FF76148C3F6]
# 	(No symbol) [0x00007FF7614BF510]
# 	(No symbol) [0x00007FF7614DF412]
# 	(No symbol) [0x00007FF7614BF0A3]
# 	(No symbol) [0x00007FF76148A778]
# 	(No symbol) [0x00007FF76148B8E1]
# 	GetHandleVerifier [0x00007FF76196FCCD+3408029]
# 	GetHandleVerifier [0x00007FF76198743F+3504143]
# 	GetHandleVerifier [0x00007FF76197B61D+3455469]
# 	GetHandleVerifier [0x00007FF7616FBDCB+835995]
# 	(No symbol) [0x00007FF7615AEB6F]
# 	(No symbol) [0x00007FF7615AA824]
# 	(No symbol) [0x00007FF7615AA9BD]
# 	(No symbol) [0x00007FF76159A1A9]
# 	BaseThreadInitThunk [0x00007FFC5F5BE8D7+23]
# 	RtlUserThreadStart [0x00007FFC60B7FBCC+44]
#
# Error extracting product info from <li>: Message: no such element: Unable to locate element: {"method":"css selector","selector":".product-productMetaInfo"}
#   (Session info: chrome=131.0.6778.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF761636CC5+28821]
# 	(No symbol) [0x00007FF7615A3850]
# 	(No symbol) [0x00007FF76144578A]
# 	(No symbol) [0x00007FF7614991BE]
# 	(No symbol) [0x00007FF7614994AC]
# 	(No symbol) [0x00007FF76148C52C]
# 	(No symbol) [0x00007FF7614BF33F]
# 	(No symbol) [0x00007FF76148C3F6]
# 	(No symbol) [0x00007FF7614BF510]
# 	(No symbol) [0x00007FF7614DF412]
# 	(No symbol) [0x00007FF7614BF0A3]
# 	(No symbol) [0x00007FF76148A778]
# 	(No symbol) [0x00007FF76148B8E1]
# 	GetHandleVerifier [0x00007FF76196FCCD+3408029]
# 	GetHandleVerifier [0x00007FF76198743F+3504143]
# 	GetHandleVerifier [0x00007FF76197B61D+3455469]
# 	GetHandleVerifier [0x00007FF7616FBDCB+835995]
# 	(No symbol) [0x00007FF7615AEB6F]
# 	(No symbol) [0x00007FF7615AA824]
# 	(No symbol) [0x00007FF7615AA9BD]
# 	(No symbol) [0x00007FF76159A1A9]
# 	BaseThreadInitThunk [0x00007FFC5F5BE8D7+23]
# 	RtlUserThreadStart [0x00007FFC60B7FBCC+44]
#
# Error extracting product info from <li>: Message: no such element: Unable to locate element: {"method":"css selector","selector":".product-productMetaInfo"}
#   (Session info: chrome=131.0.6778.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF761636CC5+28821]
# 	(No symbol) [0x00007FF7615A3850]
# 	(No symbol) [0x00007FF76144578A]
# 	(No symbol) [0x00007FF7614991BE]
# 	(No symbol) [0x00007FF7614994AC]
# 	(No symbol) [0x00007FF76148C52C]
# 	(No symbol) [0x00007FF7614BF33F]
# 	(No symbol) [0x00007FF76148C3F6]
# 	(No symbol) [0x00007FF7614BF510]
# 	(No symbol) [0x00007FF7614DF412]
# 	(No symbol) [0x00007FF7614BF0A3]
# 	(No symbol) [0x00007FF76148A778]
# 	(No symbol) [0x00007FF76148B8E1]
# 	GetHandleVerifier [0x00007FF76196FCCD+3408029]
# 	GetHandleVerifier [0x00007FF76198743F+3504143]
# 	GetHandleVerifier [0x00007FF76197B61D+3455469]
# 	GetHandleVerifier [0x00007FF7616FBDCB+835995]
# 	(No symbol) [0x00007FF7615AEB6F]
# 	(No symbol) [0x00007FF7615AA824]
# 	(No symbol) [0x00007FF7615AA9BD]
# 	(No symbol) [0x00007FF76159A1A9]
# 	BaseThreadInitThunk [0x00007FFC5F5BE8D7+23]
# 	RtlUserThreadStart [0x00007FFC60B7FBCC+44]
#
# Error extracting product info from <li>: Message: no such element: Unable to locate element: {"method":"css selector","selector":".product-productMetaInfo"}
#   (Session info: chrome=131.0.6778.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF761636CC5+28821]
# 	(No symbol) [0x00007FF7615A3850]
# 	(No symbol) [0x00007FF76144578A]
# 	(No symbol) [0x00007FF7614991BE]
# 	(No symbol) [0x00007FF7614994AC]
# 	(No symbol) [0x00007FF76148C52C]
# 	(No symbol) [0x00007FF7614BF33F]
# 	(No symbol) [0x00007FF76148C3F6]
# 	(No symbol) [0x00007FF7614BF510]
# 	(No symbol) [0x00007FF7614DF412]
# 	(No symbol) [0x00007FF7614BF0A3]
# 	(No symbol) [0x00007FF76148A778]
# 	(No symbol) [0x00007FF76148B8E1]
# 	GetHandleVerifier [0x00007FF76196FCCD+3408029]
# 	GetHandleVerifier [0x00007FF76198743F+3504143]
# 	GetHandleVerifier [0x00007FF76197B61D+3455469]
# 	GetHandleVerifier [0x00007FF7616FBDCB+835995]
# 	(No symbol) [0x00007FF7615AEB6F]
# 	(No symbol) [0x00007FF7615AA824]
# 	(No symbol) [0x00007FF7615AA9BD]
# 	(No symbol) [0x00007FF76159A1A9]
# 	BaseThreadInitThunk [0x00007FFC5F5BE8D7+23]
# 	RtlUserThreadStart [0x00007FFC60B7FBCC+44]
#
# Error extracting product info from <li>: Message: no such element: Unable to locate element: {"method":"css selector","selector":".product-productMetaInfo"}
#   (Session info: chrome=131.0.6778.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF761636CC5+28821]
# 	(No symbol) [0x00007FF7615A3850]
# 	(No symbol) [0x00007FF76144578A]
# 	(No symbol) [0x00007FF7614991BE]
# 	(No symbol) [0x00007FF7614994AC]
# 	(No symbol) [0x00007FF76148C52C]
# 	(No symbol) [0x00007FF7614BF33F]
# 	(No symbol) [0x00007FF76148C3F6]
# 	(No symbol) [0x00007FF7614BF510]
# 	(No symbol) [0x00007FF7614DF412]
# 	(No symbol) [0x00007FF7614BF0A3]
# 	(No symbol) [0x00007FF76148A778]
# 	(No symbol) [0x00007FF76148B8E1]
# 	GetHandleVerifier [0x00007FF76196FCCD+3408029]
# 	GetHandleVerifier [0x00007FF76198743F+3504143]
# 	GetHandleVerifier [0x00007FF76197B61D+3455469]
# 	GetHandleVerifier [0x00007FF7616FBDCB+835995]
# 	(No symbol) [0x00007FF7615AEB6F]
# 	(No symbol) [0x00007FF7615AA824]
# 	(No symbol) [0x00007FF7615AA9BD]
# 	(No symbol) [0x00007FF76159A1A9]
# 	BaseThreadInitThunk [0x00007FFC5F5BE8D7+23]
# 	RtlUserThreadStart [0x00007FFC60B7FBCC+44]
#
# Data successfully exported to product_data.xlsx

# %% [markdown]
# Ratings and Reviews.

# %%
def extract_comments(p_id, product_review_url):

    try:
        driver.implicitly_wait(1)
        
        rating_elements = driver.find_elements(By.CLASS_NAME, "user-review-starRating")

        review_container = driver.find_element(By.CLASS_NAME, "detailed-reviews-userReviewsContainer")
        reviews = review_container.find_elements(By.CLASS_NAME, "user-review-reviewTextWrapper")

        date_elements = driver.find_elements(By.CLASS_NAME, "user-review-left")

        for i in range(min(5, len(reviews))):
            rating = rating_elements[i].text.strip() if i < len(rating_elements) else "N/A"
            comment = reviews[i].text.strip()
            date = date_elements[i].find_elements(By.TAG_NAME, "span")[1].text.strip()

            review_data.append({
                'product_id': p_id,
                'cust_rating': rating,
                'comment': comment,
                'date': date
            })

    except Exception as e:
        print(f"Error scraping reviews for product ID {p_id}: {e}")

def extract_ratings(p_id, product_review_url):

    try:
        driver.implicitly_wait(5)
        
        avg_container = driver.find_element(By.CLASS_NAME, "index-averageRating")
        avg_ratings =  avg_container.find_element(By.TAG_NAME, "span").text
        

        ratings_data.append({
            "product_id": p_id,
            "avg": avg_ratings
        })

    except Exception as e:
        print(f"Error scraping ratings for product ID {p_id}: {e}")

df = pd.read_csv('products.csv')

ratings_data = []
review_data = []
review_url = 'https://www.myntra.com/reviews/'

#Iterates through all the product_id in the stored csv file and creates a link form each product.
p_ids = df['id']
for p_id in p_ids:
    product_review_url = review_url + str(p_id)
    driver.get(product_review_url)
    extract_comments(p_id, product_review_url)
    extract_ratings(p_id, product_review_url)

df_reviews = pd.DataFrame(review_data)
df_reviews.to_csv('reviews.csv', index=False)
print("reviews.csv saved successfully.")

df_ratings = pd.DataFrame(ratings_data)
df_ratings.to_csv('ratings.csv', index=False)
print("ratings.csv saved successfully")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 5
#       1 li_container= driver.find_element(by=By.CLASS_NAME, value="results-base")
#       3 li_container.text
# ----> 5 for id in li_container:
#       6     print(id)
#
# TypeError: 'WebElement' object is not iterable
